# %% [markdown]
# <a href="https://colab.research.google.com/github/danieIinacio/Colab-gen/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# * CARREGAMENTO DE DADOS

# %%
df_customer = pd.read_csv('/content/customers_data.csv')
df_carbon = pd.read_csv('/content/carbon_offsets.csv')
df_rentals = pd.read_json('/content/rentals_data.json')
df_vehicles = pd.read_json('/content/vehicles_data.json')

# %%
# Pré analise de dados
# Comandos Importantes
# .info()
# .head()
# .columns()

# %% [markdown]
# * Costumers _ age = valor ausente
# * Rentals _ dayly_rate = calor menor que 0 / dat invalida
# * Vehicles _ dado ausente
# * Carbon _

# %%
df_customer.info()
df_customer.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    4 non-null      object
#  1   customer_type  4 non-null      object
#  2   age            3 non-null      float64
#  3   city           4 non-null      object
#  4   loyalty_score  4 non-null      int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 292.0+ bytes
#   customer_id customer_type   age       city  loyalty_score
# 0        C001    Recorrente  35.0  São Paulo             90
# 1        C002          Novo  28.0   Curitiba             60
# 2        C003          Novo   NaN   Salvador             50
# 3        C004   Corporativo  45.0  São Paulo             95

# %%
df_carbon.info()
df_carbon.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                2 non-null      int64
#  1   carbon_offset_tons  2 non-null      int64
#  2   cost_usd            2 non-null      int64
# dtypes: int64(3)
# memory usage: 180.0 bytes
#    year  carbon_offset_tons  cost_usd
# 0  2023                 120      1800
# 1  2024                 200      3000

# %%
df_rentals.info()
df_rentals.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rental_id    5 non-null      int64
#  1   customer_id  5 non-null      object
#  2   vehicle_id   5 non-null      object
#  3   start_date   5 non-null      object
#  4   end_date     5 non-null      object
#  5   city         5 non-null      object
#  6   daily_rate   5 non-null      int64
#  7   distance_km  5 non-null      int64
# dtypes: int64(3), object(5)
# memory usage: 452.0+ bytes
#    rental_id customer_id vehicle_id    start_date    end_date            city  \
# 0       2001        C001       V100    2024-01-05  2024-01-08       São Paulo
# 1       2002        C002       V101    2024/01/10  2024/01/12        Curitiba
# 2       2003        C003       V102  invalid_date  2024-01-15        Salvador
# 3       2004        C004       V103    2024-02-01  2024-02-10       São Paulo
# 4       2005        C001       V104    2024-02-15  2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km
# 0         180          320
# 1         150          210
# 2         220            0
# 3         300          980
# 4        -100          120

# %%
df_vehicles.info()
df_vehicles.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   vehicle_id    5 non-null      object
#  1   model         5 non-null      object
#  2   fuel_type     5 non-null      object
#  3   co2_g_per_km  4 non-null      float64
#  4   category      5 non-null      object
# dtypes: float64(1), object(4)
# memory usage: 332.0+ bytes
#   vehicle_id          model fuel_type  co2_g_per_km   category
# 0       V100           HB20  Gasolina         120.0  Econômico
# 1       V101        Corolla  Gasolina         160.0      Sedan
# 2       V102        Compass    Diesel         180.0        SUV
# 3       V103  Tesla Model 3  Elétrico           0.0   Elétrico
# 4       V104           Onix  Gasolina           NaN  Econômico

# %%
#df_vehicles.columns()
#df_rentals.columns()
#df_carbon.columns()
#df_customer.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4025334740.py in <cell line: 0>()
# ----> 1 df_vehicles.columns()
#       2 df_rentals.columns()
#       3 df_carbon.columns()
#       4 df_customer.columns()
#
# TypeError: 'Index' object is not callable

# %% [markdown]
# * IDENTIFICAÇÃO DE DADOS
#
# . Datas
#
# . Valores Negativos
#
# . DataTypes

# %%
# customers - age -Valor ausente
df_customer["age"].fillna(df_customer["age"].median(), inplace=True)

display(df_customer)
# Out:
# /tmp/ipython-input-2120772908.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_customer["age"].fillna(df_customer["age"].median(), inplace=True)
#   customer_id customer_type   age       city  loyalty_score
# 0        C001    Recorrente  35.0  São Paulo             90
# 1        C002          Novo  28.0   Curitiba             60
# 2        C003          Novo  35.0   Salvador             50
# 3        C004   Corporativo  45.0  São Paulo             95

# %%
# rentals - daily_rate - valor menor que zero
df_rentals.loc[df_rentals["daily_rate"] < 0, "daily_rate"] = None
df_rentals["daily_rate"].fillna(df_rentals["daily_rate"].median(), inplace=True)
display(df_rentals)
# Out:
# /tmp/ipython-input-4246566676.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_rentals["daily_rate"].fillna(df_rentals["daily_rate"].median(), inplace=True)
#    rental_id customer_id vehicle_id    start_date    end_date            city  \
# 0       2001        C001       V100    2024-01-05  2024-01-08       São Paulo
# 1       2002        C002       V101    2024/01/10  2024/01/12        Curitiba
# 2       2003        C003       V102  invalid_date  2024-01-15        Salvador
# 3       2004        C004       V103    2024-02-01  2024-02-10       São Paulo
# 4       2005        C001       V104    2024-02-15  2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km
# 0       180.0          320
# 1       150.0          210
# 2       220.0            0
# 3       300.0          980
# 4       200.0          120

# %%
# Vehicles - co2_g_Per_km - Dado ausente (colocar o valor economico)
media_economico = df_vehicles.loc[
    df_vehicles["category"] == "Econômico", "co2_g_per_km"
].mean()

df_vehicles["co2_g_per_km"].fillna(media_economico, inplace=True)
display(df_vehicles)
# Out:
# /tmp/ipython-input-2300974412.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_vehicles["co2_g_per_km"].fillna(media_economico, inplace=True)
#   vehicle_id          model fuel_type  co2_g_per_km   category
# 0       V100           HB20  Gasolina         120.0  Econômico
# 1       V101        Corolla  Gasolina         160.0      Sedan
# 2       V102        Compass    Diesel         180.0        SUV
# 3       V103  Tesla Model 3  Elétrico           0.0   Elétrico
# 4       V104           Onix  Gasolina         120.0  Econômico

# %%
# Vehicles - co2_g_Per_km - Dado ausente (colocar medio)
df_vehicles["co2_g_per_km"].fillna(df_vehicles["co2_g_per_km"].mean(), inplace=True)
display(df_vehicles)
# Out:
# /tmp/ipython-input-154693108.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_vehicles["co2_g_per_km"].fillna(df_vehicles["co2_g_per_km"].mean(), inplace=True)
#   vehicle_id          model fuel_type  co2_g_per_km   category
# 0       V100           HB20  Gasolina         120.0  Econômico
# 1       V101        Corolla  Gasolina         160.0      Sedan
# 2       V102        Compass    Diesel         180.0        SUV
# 3       V103  Tesla Model 3  Elétrico           0.0   Elétrico
# 4       V104           Onix  Gasolina         115.0  Econômico

# %%
# Rentals - daily_rate esta como string
df_rentals["daily_rate"] = pd.to_numeric(df_rentals["daily_rate"], errors="coerce")
display(df_rentals)
# Out:
#    rental_id customer_id vehicle_id    start_date    end_date            city  \
# 0       2001        C001       V100    2024-01-05  2024-01-08       São Paulo
# 1       2002        C002       V101    2024/01/10  2024/01/12        Curitiba
# 2       2003        C003       V102  invalid_date  2024-01-15        Salvador
# 3       2004        C004       V103    2024-02-01  2024-02-10       São Paulo
# 4       2005        C001       V104    2024-02-15  2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km
# 0         180          320
# 1         150          210
# 2         220            0
# 3         300          980
# 4        -100          120

# %%
# Rentals - Data Invalida
df_rentals["start_date"] = pd.to_datetime(df_rentals["start_date"], errors="coerce")
df_rentals["end_date"] = pd.to_datetime(df_rentals["end_date"], errors="coerce")
display(df_rentals)
# Out:
#    rental_id customer_id vehicle_id start_date   end_date            city  \
# 0       2001        C001       V100 2024-01-05 2024-01-08       São Paulo
# 1       2002        C002       V101        NaT        NaT        Curitiba
# 2       2003        C003       V102        NaT 2024-01-15        Salvador
# 3       2004        C004       V103 2024-02-01 2024-02-10       São Paulo
# 4       2005        C001       V104 2024-02-15 2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km
# 0         180          320
# 1         150          210
# 2         220            0
# 3         300          980
# 4        -100          120

# %% [markdown]
# Calcule a duração de cada locação (em dias)
#
# .Calcule a receita total por locação
#
# .Faça o merge com a base de veículos
#
# .Calcule a emissão de CO₂ por locação
#
# .Extraia ano e mês da data de início da locação

# %%
# criar backup de dados
df_carbon_clean = df_carbon
df_rentals_clean = df_rentals
df_customer_clean = df_customer
df_vehicles_clean = df_vehicles

# %%
# Calcule a duração de cada locação (em dias).
df_rentals_clean['dias_locacao'] = (
    df_rentals_clean['end_date'] - df_rentals_clean['start_date']
    ).dt.days
display(df_rentals_clean)
# Out:
#    rental_id customer_id vehicle_id start_date   end_date            city  \
# 0       2001        C001       V100 2024-01-05 2024-01-08       São Paulo
# 1       2002        C002       V101        NaT        NaT        Curitiba
# 2       2003        C003       V102        NaT 2024-01-15        Salvador
# 3       2004        C004       V103 2024-02-01 2024-02-10       São Paulo
# 4       2005        C001       V104 2024-02-15 2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km  dias_locacao
# 0       180.0          320           3.0
# 1       150.0          210           NaN
# 2       220.0            0           NaN
# 3       300.0          980           9.0
# 4       200.0          120           1.0

# %%
# Calcule a receita total por locação.
# valor da diária = daily_rate
# dais de locação * valor da diaria
df_rentals_clean['receita_total'] = df_rentals_clean['dias_locacao'] * df_rentals_clean['daily_rate']

# %%
# Faça o merge com a base de veículos.
df_consolidado = df_rentals_clean.merge(df_vehicles_clean, on='vehicle_id')

df_consolidado = df_consolidado.merge(df_customer_clean, on='customer_id')

# %%
# Calcule a emissão de CO₂ por locação.
df_consolidado['co2_emitido'] = df_consolidado['co2_g_per_km'] * df_consolidado['distance_km']

# %%
# Extraia ano e mês da data de início da locação.
# para extrair informções da data temos
# .dt.days - dia
# .dt.month - mes
# .dt.year - ano
# .dt.weekday - dia da semana
df_consolidado['mes'] = df_consolidado['start_date'].dt.month
df_consolidado['ano'] = df_consolidado['start_date'].dt.year
df_consolidado['dia_da_semana'] = df_consolidado['start_date'].dt.weekday

display(df_consolidado)
# Out:
#    rental_id customer_id vehicle_id start_date   end_date          city_x  \
# 0       2001        C001       V100 2024-01-05 2024-01-08       São Paulo
# 1       2002        C002       V101        NaT        NaT        Curitiba
# 2       2003        C003       V102        NaT 2024-01-15        Salvador
# 3       2004        C004       V103 2024-02-01 2024-02-10       São Paulo
# 4       2005        C001       V104 2024-02-15 2024-02-16  Rio de Janeiro
#
#    daily_rate  distance_km  dias_locacao  receita_total  ... co2_g_per_km  \
# 0       180.0          320           3.0          540.0  ...        120.0
# 1       150.0          210           NaN            NaN  ...        160.0
# 2       220.0            0           NaN            NaN  ...        180.0
# 3       300.0          980           9.0         2700.0  ...          0.0
# 4       200.0          120           1.0          200.0  ...        115.0
#
#     category  customer_type   age     city_y  loyalty_score co2_emitido  mes  \
# 0  Econômico     Recorrente  35.0  São Paulo             90     38400.0  1.0
# 1      Sedan           Novo  28.0   Curitiba             60     33600.0  NaN
# 2        SUV           Novo  35.0   Salvador             50         0.0  NaN
# 3   Elétrico    Corporativo  45.0  São Paulo             95         0.0  2.0
# 4  Econômico     Recorrente  35.0  São Paulo             90     13800.0  2.0
#
#       ano  dia_da_semana
# 0  2024.0            4.0
# 1     NaN            NaN
# 2     NaN            NaN
# 3  2024.0            3.0
# 4  2024.0            3.0
#
# [5 rows x 22 columns]
